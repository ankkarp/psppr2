# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

from tree import MST

# %%
mst = MST()
x, _ = make_blobs(n_samples=10, centers=1, n_features=2)
plt.scatter(*x.T)

# %%
import numpy as np

np.argmin(np.array([2, 1, 2, 1]))
# Out:
# 1

# %%
from contextlib import redirect_stdout

with open('prima.log', 'w', encoding='utf-8') as f:
    with redirect_stdout(f):
        path, total_weight = mst.prima(x)

# %%
total_weight
# Out:
# 8.379432803693179

# %%
path
# Out:
# array([[-9.01733136,  8.71704289],
#        [-8.83748496,  9.40307933],
#        [-7.7292853 ,  8.32247915],
#        [-7.33621088,  8.63435943],
#        [-6.68770542,  9.11865116],
#        [-6.62235863,  9.35706944],
#        [-7.1237108 , 10.27909602],
#        [-6.44266527, 10.83751141],
#        [-6.57386886, 11.12001155],
#        [-5.19130605,  9.2541069 ]])
